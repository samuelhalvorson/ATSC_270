# %% [markdown]
# # ASSIGNMENT #4 - SURFACE WEATHER DATA #
# Due: 31 March 2024 @ 11:59p

# %% [markdown]
# Purpose:\
# The purpose of this assignment is to continue to strengthen skills with reading in data by reading in surface observations from a text file.  The data is then plotted on a map to begin to familiarize with plotting weather data on maps.
#
# Overview:\
# In this assignment you will read in surface weather data, quality control that data, and plot that data .
#
#
# | | UPDATE TO YOUR INFORMATION |
# | :- | :- |
# | Created By | Jared W. Marquis |
# | Creation Date | 18 January 2024 |
# | Course | ATSC 270 - Computer Concepts in Meteorology |

# %%
### UPDATE TO YOUR INFORMATION ###
#information allowing anyone with the code to print the author and contact information
__author__    = "Sam Halvorson"
__contact__   = "samuel.t.halvorson@und.edu"

# %% [markdown]
# ### IMPORT REQUIRED LIBRARIES ###

# %%
import numpy as np

import metpy.calc as mpcalc
from metpy.units import units
from metpy.plots import current_weather, sky_cover, StationPlot, simple_layout
from metpy.io import metar

import pandas as pd

import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### OPEN OBSERVATIONS TEXT FILE ###
# Open the text file containing the surface observations using the metpy metar reader -> metar.parse_metar_file(filename).

# %%
data = metar.parse_metar_file("metar_20240112_2100.txt", year=2024, month=1)

data.air_temperature = (data.air_temperature * 9/5) + 32
data.dew_point_temperature = (data.dew_point_temperature * 9/5) + 32

#print(data)
#print(data.loc["KMSP"])

# %% [markdown]
# ### REMOVE DATA THAT IS INCOMPLETE ###
# Just remove data with no wind direction or wind speed.

# %%
data.dropna(how="any", subset=["wind_direction","wind_speed"])



print(data)
# Out:
#            station_id  latitude   longitude  elevation           date_time  \
# station_id
# KGYH             KGYH     34.75  -82.380000      292.0 2024-01-12 20:47:00
# KMFV             KMFV     37.63  -75.770000       15.0 2024-01-12 20:55:00
# KPLD             KPLD     40.45  -84.983333      282.0 2024-01-12 20:55:00
# KIKT             KIKT     28.52  -88.280000       25.0 2024-01-12 20:50:00
# PAKU             PAKU     70.31 -149.580000        2.0 2024-01-12 20:45:00
# ...               ...       ...         ...        ...                 ...
# OIYY             OIYY     31.90   54.280000     1236.0 2024-01-12 21:50:00
# ORNI             ORNI     31.98   44.400000       53.0 2024-01-14 21:00:00
# NFTV             NFTV    -18.57 -173.970000       71.0 2024-01-12 21:00:00
# NFTL             NFTL    -19.78 -174.330000        3.0 2024-01-12 21:00:00
# NFTF             NFTF    -21.23 -175.150000       38.0 2024-01-12 21:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGYH                  60.0        12.0        NaN    4828.032         +RA
# KMFV                 100.0         6.0        NaN   16093.440         NaN
# KPLD                 130.0        10.0        NaN    8046.720         -SN
# KIKT                 240.0        22.0       32.0    4828.032          BR
# PAKU                 100.0        21.0        NaN    4828.032        BLSN
# ...                    ...         ...        ...         ...         ...
# OIYY                 120.0         4.0        NaN   10000.000         NaN
# ORNI                 240.0         7.0        NaN    6000.000         NaN
# NFTV                  90.0        15.0        NaN    9999.000       -SHRA
# NFTL                  90.0        22.0        NaN    9999.000         NaN
# NFTF                  90.0        16.0        NaN    9999.000         NaN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGYH        ...            44.6                  42.8     29.61
# KMFV        ...            48.2                  41.0     29.99
# KPLD        ...            33.8                  33.8     29.16
# KIKT        ...            73.4                  69.8     29.68
# PAKU        ...             5.0                   3.2     29.96
# ...         ...             ...                   ...       ...
# OIYY        ...            51.8                  26.6     29.88
# ORNI        ...            51.8                  42.8     30.03
# NFTV        ...            82.4                  75.2     29.88
# NFTL        ...            84.2                  73.4     29.91
# NFTF        ...            80.6                  73.4     29.94
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGYH                        65                 10                   0
# KMFV                         0                  0                   0
# KPLD                        71                  0                   0
# KIKT                        10                  0                   0
# PAKU                        38                 10                   0
# ...                        ...                ...                 ...
# OIYY                         0                  0                   0
# ORNI                         0                  0                   0
# NFTV                        80                  0                   0
# NFTL                         0                  0                   0
# NFTF                         0                  0                   0
#
#                   remarks  air_pressure_at_sea_level eastward_wind  \
# station_id
# KGYH                                         1003.81    -10.392305
# KMFV        AO2 T00890049                    1015.92     -5.908847
# KPLD            AO2 P0007                     989.18     -7.660444
# KIKT                  A01                    1005.29     19.052559
# PAKU                                         1014.89    -20.680963
# ...                   ...                        ...           ...
# OIYY                                         1012.21     -3.464102
# ORNI                                         1017.39      6.062178
# NFTV                                         1011.92    -15.000000
# NFTL                                         1013.28    -22.000000
# NFTF                                         1014.11    -16.000000
#
#             northward_wind
# station_id
# KGYH         -6.000000e+00
# KMFV          1.041889e+00
# KPLD          6.427876e+00
# KIKT          1.100000e+01
# PAKU          3.646612e+00
# ...                    ...
# OIYY          2.000000e+00
# ORNI          3.500000e+00
# NFTV         -9.184851e-16
# NFTL         -1.347111e-15
# NFTF         -9.797174e-16
#
# [9383 rows x 31 columns]

# %% [markdown]
# ### PLOT MAP ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10), dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

fig.tight_layout()

#save the map as empty_map.png
plt.savefig("empty_map.png")

# %% [markdown]
# ### PLOT A NEW MAP BUT ADD SURFACE OBS LOCATIONS ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10), dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND, zorder=0)
ax.add_feature(cfeature.OCEAN, zorder=1)
ax.add_feature(cfeature.LAKES, zorder=1)
ax.add_feature(cfeature.COASTLINE, zorder=2)
ax.add_feature(cfeature.STATES, zorder=3)
ax.add_feature(cfeature.BORDERS, zorder=3)

#
plt.scatter(data.longitude, data.latitude,
            color="dodgerblue",
            s=5,
            alpha=0.5,
            transform=ccrs.PlateCarree(), zorder=3)


#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

fig.tight_layout()

#plot surface obs using scatter plot


fig.tight_layout()
#save the map as obs_locations.png

plt.savefig("obs_locations.png")

# %% [markdown]
# ### WAY TOO MANY OBS ###
# There are way too many obs for us to be able to actually see what the weather is.  We need to "thin" the obs in areas of very high densiy.
#
# We'll do this using the *metpy.calc.reduce_point_density* function.
#
# Find a density that works well for you.  The units for density are meters, so 100000 is roughly one observation/100km.

# %%
#first convert the lat/lon to map projection coordinates
locs = proj.transform_points(ccrs.PlateCarree(),data['longitude'].values,data['latitude'].values)

#now thin the data
dataThin = data[mpcalc.reduce_point_density(locs, 250000)]
print(dataThin)
# Out:
#            station_id  latitude   longitude  elevation           date_time  \
# station_id
# KGYH             KGYH     34.75  -82.380000      292.0 2024-01-12 20:47:00
# KMFV             KMFV     37.63  -75.770000       15.0 2024-01-12 20:55:00
# KPLD             KPLD     40.45  -84.983333      282.0 2024-01-12 20:55:00
# KIKT             KIKT     28.52  -88.280000       25.0 2024-01-12 20:50:00
# PAKU             PAKU     70.31 -149.580000        2.0 2024-01-12 20:45:00
# ...               ...       ...         ...        ...                 ...
# OIBB             OIBB     28.97   50.820000       19.0 2024-01-12 21:00:00
# OIZB             OIZB     31.10   61.550000      489.0 2024-01-12 21:00:00
# OIZI             OIZI     27.23   60.720000      591.0 2024-01-12 21:00:00
# NFTV             NFTV    -18.57 -173.970000       71.0 2024-01-12 21:00:00
# NFTF             NFTF    -21.23 -175.150000       38.0 2024-01-12 21:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGYH                  60.0        12.0        NaN    4828.032         +RA
# KMFV                 100.0         6.0        NaN   16093.440         NaN
# KPLD                 130.0        10.0        NaN    8046.720         -SN
# KIKT                 240.0        22.0       32.0    4828.032          BR
# PAKU                 100.0        21.0        NaN    4828.032        BLSN
# ...                    ...         ...        ...         ...         ...
# OIBB                 120.0         6.0        NaN   10000.000         NaN
# OIZB                  10.0         6.0        NaN   10000.000         NaN
# OIZI                  50.0         4.0        NaN   10000.000         NaN
# NFTV                  90.0        15.0        NaN    9999.000       -SHRA
# NFTF                  90.0        16.0        NaN    9999.000         NaN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGYH        ...            44.6                  42.8     29.61
# KMFV        ...            48.2                  41.0     29.99
# KPLD        ...            33.8                  33.8     29.16
# KIKT        ...            73.4                  69.8     29.68
# PAKU        ...             5.0                   3.2     29.96
# ...         ...             ...                   ...       ...
# OIBB        ...            66.2                  53.6     29.97
# OIZB        ...            37.4                  14.0     29.88
# OIZI        ...            53.6                  23.0     30.03
# NFTV        ...            82.4                  75.2     29.88
# NFTF        ...            80.6                  73.4     29.94
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGYH                        65                 10                   0
# KMFV                         0                  0                   0
# KPLD                        71                  0                   0
# KIKT                        10                  0                   0
# PAKU                        38                 10                   0
# ...                        ...                ...                 ...
# OIBB                         0                  0                   0
# OIZB                         0                  0                   0
# OIZI                         0                  0                   0
# NFTV                        80                  0                   0
# NFTF                         0                  0                   0
#
#                   remarks  air_pressure_at_sea_level eastward_wind  \
# station_id
# KGYH                                         1003.81    -10.392305
# KMFV        AO2 T00890049                    1015.92     -5.908847
# KPLD            AO2 P0007                     989.18     -7.660444
# KIKT                  A01                    1005.29     19.052559
# PAKU                                         1014.89    -20.680963
# ...                   ...                        ...           ...
# OIBB                A2997                    1015.27     -5.196152
# OIZB                                         1014.50     -1.041889
# OIZI                                         1017.61     -3.064178
# NFTV                                         1011.92    -15.000000
# NFTF                                         1014.11    -16.000000
#
#             northward_wind
# station_id
# KGYH         -6.000000e+00
# KMFV          1.041889e+00
# KPLD          6.427876e+00
# KIKT          1.100000e+01
# PAKU          3.646612e+00
# ...                    ...
# OIBB          3.000000e+00
# OIZB         -5.908847e+00
# OIZI         -2.571150e+00
# NFTV         -9.184851e-16
# NFTF         -9.797174e-16
#
# [888 rows x 31 columns]

# %% [markdown]
# ### SAVE OBS LOCATIONS ON NEW MAP ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10), dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND, zorder=0)
ax.add_feature(cfeature.OCEAN, zorder=1)
ax.add_feature(cfeature.LAKES, zorder=1)
ax.add_feature(cfeature.COASTLINE, zorder=2)
ax.add_feature(cfeature.STATES, zorder=3)
ax.add_feature(cfeature.BORDERS, zorder=3)

#
plt.scatter(dataThin.longitude, dataThin.latitude,
            color="black",
            s=9,
            alpha=0.5,
            transform=ccrs.PlateCarree(), zorder=3)


#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

fig.tight_layout()

#plot surface obs using scatter plot


fig.tight_layout()

#save the map as obs_locations_thinned.png
plt.savefig("obs_locations_thinned.png")

# %% [markdown]
# ### ONCE YOU'RE HAPPY WITH THE DENSITY, PLOT SURFACE STATIONS ###
# For this use the *StationPlot* object in metpy -> https://unidata.github.io/MetPy/latest/api/generated/metpy.plots.StationPlot.html

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10), dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND, zorder=0)
ax.add_feature(cfeature.OCEAN, zorder=1)
ax.add_feature(cfeature.LAKES, zorder=1)
ax.add_feature(cfeature.COASTLINE, zorder=2)
ax.add_feature(cfeature.STATES, zorder=3)
ax.add_feature(cfeature.BORDERS, zorder=3)


#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

fig.tight_layout()

stationplots = StationPlot(ax, dataThin.longitude, dataThin.latitude, transform=ccrs.PlateCarree(), clip_on=True)

simple_layout.plot(stationplots, dataThin)




fig.tight_layout()

#save the map as simple_surface_obs.png
plt.savefig("simple_surface_obs.png")

# %% [markdown]
# ### PLOT NORTHERN PLAINS ###
# Now we are going to focus on the Northern Great Plains and make a custom layout.<br>
# We will set the extent to 150W to 90W and 40N to 50N.<br>
# We will also need to re-thin the data since we will be zoomed in and can see more obs.<br><br>
# Data that will be plotted:<br>
#  - Temperature in the top left
#  - Dewpoint in bottom left
#  - Pressure in top right
#  - Station ID in bottom right
#  - Current weather on left
#  - Visibility in miles on far left
#  - Wind barb in black
#  - Wind gust barb in red

# %%
#rethin data (90km works well)

#first convert the lat/lon to map projection coordinates
#locs = proj.transform_points(ccrs.PlateCarree(),data['longitude'].values,data['latitude'].values)

#now thin the data
dataThin2 = data[mpcalc.reduce_point_density(locs, 90000)]
print(dataThin2)
# Out:
#            station_id  latitude   longitude  elevation           date_time  \
# station_id
# KGYH             KGYH     34.75  -82.380000      292.0 2024-01-12 20:47:00
# KMFV             KMFV     37.63  -75.770000       15.0 2024-01-12 20:55:00
# KPLD             KPLD     40.45  -84.983333      282.0 2024-01-12 20:55:00
# KIKT             KIKT     28.52  -88.280000       25.0 2024-01-12 20:50:00
# PAKU             PAKU     70.31 -149.580000        2.0 2024-01-12 20:45:00
# ...               ...       ...         ...        ...                 ...
# OINN             OINN     36.67   51.470000      -19.0 2024-01-12 21:00:00
# OIZH             OIZH     29.47   60.920000     1370.0 2024-01-12 21:00:00
# NFTV             NFTV    -18.57 -173.970000       71.0 2024-01-12 21:00:00
# NFTL             NFTL    -19.78 -174.330000        3.0 2024-01-12 21:00:00
# NFTF             NFTF    -21.23 -175.150000       38.0 2024-01-12 21:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGYH                  60.0        12.0        NaN    4828.032         +RA
# KMFV                 100.0         6.0        NaN   16093.440         NaN
# KPLD                 130.0        10.0        NaN    8046.720         -SN
# KIKT                 240.0        22.0       32.0    4828.032          BR
# PAKU                 100.0        21.0        NaN    4828.032        BLSN
# ...                    ...         ...        ...         ...         ...
# OINN                   0.0         0.0        NaN    9999.000         NaN
# OIZH                 220.0        10.0        NaN   10000.000         NaN
# NFTV                  90.0        15.0        NaN    9999.000       -SHRA
# NFTL                  90.0        22.0        NaN    9999.000         NaN
# NFTF                  90.0        16.0        NaN    9999.000         NaN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGYH        ...            44.6                  42.8     29.61
# KMFV        ...            48.2                  41.0     29.99
# KPLD        ...            33.8                  33.8     29.16
# KIKT        ...            73.4                  69.8     29.68
# PAKU        ...             5.0                   3.2     29.96
# ...         ...             ...                   ...       ...
# OINN        ...            48.2                  44.6     29.59
# OIZH        ...            53.6                  24.8     29.97
# NFTV        ...            82.4                  75.2     29.88
# NFTL        ...            84.2                  73.4     29.91
# NFTF        ...            80.6                  73.4     29.94
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGYH                        65                 10                   0
# KMFV                         0                  0                   0
# KPLD                        71                  0                   0
# KIKT                        10                  0                   0
# PAKU                        38                 10                   0
# ...                        ...                ...                 ...
# OINN                         0                  0                   0
# OIZH                         0                  0                   0
# NFTV                        80                  0                   0
# NFTL                         0                  0                   0
# NFTF                         0                  0                   0
#
#                   remarks  air_pressure_at_sea_level eastward_wind  \
# station_id
# KGYH                                         1003.81    -10.392305
# KMFV        AO2 T00890049                    1015.92     -5.908847
# KPLD            AO2 P0007                     989.18     -7.660444
# KIKT                  A01                    1005.29     19.052559
# PAKU                                         1014.89    -20.680963
# ...                   ...                        ...           ...
# OINN                                         1002.26     -0.000000
# OIZH                A2999                    1014.45      6.427876
# NFTV                                         1011.92    -15.000000
# NFTL                                         1013.28    -22.000000
# NFTF                                         1014.11    -16.000000
#
#             northward_wind
# station_id
# KGYH         -6.000000e+00
# KMFV          1.041889e+00
# KPLD          6.427876e+00
# KIKT          1.100000e+01
# PAKU          3.646612e+00
# ...                    ...
# OINN         -0.000000e+00
# OIZH          7.660444e+00
# NFTV         -9.184851e-16
# NFTL         -1.347111e-15
# NFTF         -9.797174e-16
#
# [2121 rows x 31 columns]

# %%
#create wind gust vectors
#do this by multiplying each component by the ratio of gust to speed

u = dataThin2.eastward_wind.values * units("knots")
v = dataThin2.northward_wind.values * units("knots")
gustSpeed = dataThin2.wind_gust.values * units("knots")

windDirection = mpcalc.wind_direction(u,v)

#print(windDirection)

uGust, vGust = mpcalc.wind_components(gustSpeed, windDirection)

#print(uGust[5])
#print(vGust[3])

# %%
#map projection
proj = ccrs.LambertConformal(central_longitude=-95,central_latitude=35)

#create figure
fig = plt.figure(figsize=(10,10),dpi=100)
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the Northern Plains
ax.set_extent((-105, -90, 40, 50))


#create stationplot (will actually need to create 2 to handle wind gusts)
stationplots2 = StationPlot(ax, dataThin2.longitude, dataThin2.latitude, transform=ccrs.PlateCarree(), clip_on=True)

#temperature in red
stationplots2.plot_parameter((-1,1), dataThin2['air_temperature'].values, color='red')

#dewpoint in dark green
stationplots2.plot_parameter((-1,-1), dataThin2['dew_point_temperature'].values, color='darkgreen')

#pressure (need to format to be the final 3 digits)
stationplots2.plot_parameter((1,1), dataThin2['air_pressure_at_sea_level'].values, formatter=lambda v: format(10 * v, '.0f')[-3:])

#station ID in dark blue
stationplots2.plot_text((1.5,-1), dataThin2['station_id'].values, color='darkblue')


#visibility in black (need to convert from meters to miles)
vis = dataThin2["visibility"].values * units("meters")
vis = vis.to("miles")

stationplots2.plot_text((1.5,-1), vis, color='black')

#wind gust in red

#wind in black

#cloud cover

#current weather

#save the map as surface_obs.png
# Out:
# TextCollection
# Error in callback <function _draw_all_if_interactive at 0x7f2b35dbe3e0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:538, in GeoAxes.draw(self, renderer, **kwargs)
#     533         self.imshow(img, extent=extent, origin=origin,
#     534                     transform=factory.crs, *factory_args[1:],
#     535                     **factory_kwargs)
#     536 self._done_img_factory = True
# --> 538 return super().draw(renderer=renderer, **kwargs)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/metpy/plots/_mpl.py:206, in TextCollection.draw(self, renderer)
#     203     continue
#     205 self._text = t  # hack to allow self._get_layout to work
# --> 206 _, info, _ = self._get_layout(renderer)
#     207 self._text = ''
#     209 for line, _, x, y in info:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/text.py:365, in Text._get_layout(self, renderer)
#     359 """
#     360 Return the extent (bbox) of the text together with
#     361 multiple-alignment information. Note that it returns an extent
#     362 of a rotated text when necessary.
#     363 """
#     364 thisx, thisy = 0.0, 0.0
# --> 365 lines = self._get_wrapped_text().split("\n")  # Ensures lines is not empty.
#     367 ws = []
#     368 hs = []
#
# AttributeError: 'numpy.float64' object has no attribute 'split'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2155     # we do this instead of `self.figure.draw_without_rendering`
#    2156     # so that we can inject the orientation
#    2157     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158         self.figure.draw(renderer)
#    2159 if bbox_inches:
#    2160     if bbox_inches == "tight":
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:538, in GeoAxes.draw(self, renderer, **kwargs)
#     533         self.imshow(img, extent=extent, origin=origin,
#     534                     transform=factory.crs, *factory_args[1:],
#     535                     **factory_kwargs)
#     536 self._done_img_factory = True
# --> 538 return super().draw(renderer=renderer, **kwargs)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/metpy/plots/_mpl.py:206, in TextCollection.draw(self, renderer)
#     203     continue
#     205 self._text = t  # hack to allow self._get_layout to work
# --> 206 _, info, _ = self._get_layout(renderer)
#     207 self._text = ''
#     209 for line, _, x, y in info:
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/text.py:365, in Text._get_layout(self, renderer)
#     359 """
#     360 Return the extent (bbox) of the text together with
#     361 multiple-alignment information. Note that it returns an extent
#     362 of a rotated text when necessary.
#     363 """
#     364 thisx, thisy = 0.0, 0.0
# --> 365 lines = self._get_wrapped_text().split("\n")  # Ensures lines is not empty.
#     367 ws = []
#     368 hs = []
#
# AttributeError: 'numpy.float64' object has no attribute 'split'
